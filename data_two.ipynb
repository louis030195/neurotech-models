# %%
# !wget http://mindbigdata.com/opendb/MindBigData-IN-v1.06.zip && unzip MindBigData-IN-v1.06.zip

# %%
import pandas as pd
import numpy as np
import pywt
def pad_sequences(sequences):
    # Get the length of the longest sequence
    max_length = max(len(seq) for seq in sequences)
    
    # Create a new list of sequences, each padded to the max_length with zeros at the end
    padded_sequences = np.zeros((len(sequences), max_length))
    for i, seq in enumerate(sequences):
        padded_sequences[i, :len(seq)] = seq

    return padded_sequences

# read IN.txt into dataframe
columns = ["id", "event", "device", "channel", "code", "size", "data"]

df = pd.read_csv("IN.txt", delimiter="\t", names=columns)

# Preprocess the 'data' column
df['data'] = df['data'].apply(lambda x: [float(i) for i in x.split(',')])

# group by event
df = df.groupby('event').agg(list)

# merge code from list to integer (eg [0, 0, 0, 0, 0] -> 0)
df['code'] = df['code'].apply(lambda x: x[0])

# flatten data
df['data'] = df['data'].apply(lambda x: np.array(x).flatten())

df.drop(columns=['id', 'device', 'size'], inplace=True)

# Convert 'channel' and 'data' columns to list
channels = df['channel'].tolist()
data = df['data'].tolist()

# Pad the sequences
padded_data = pad_sequences(data)

# Reshape to your desired dimensions
X = padded_data.reshape(len(df) // 5, -1, 5)

# Normalize across the last dimension
X = X / np.linalg.norm(X, axis=1, keepdims=True)

# Convert 'code' column to list
code = df['code'].tolist()

# Convert list to numpy array
Y = np.array(code)
Y = Y.reshape(len(Y) // 5, 5)

def apply_dwt(data):
    # apply discrete wavelet transform
    # 'db4' is the name of wavelet to use, you might want to choose this according to your needs
    coeffs = pywt.wavedec(data, 'db4', level=6)
    
    # concatenate and return the result
    return np.concatenate(coeffs)

# Apply DWT transform on each data instance
X = np.apply_along_axis(apply_dwt, axis=1, arr=X)

# Assuming that you want to use 80% of data for training and remaining 20% for testing
num_train = int(0.8 * len(X))

# For X
X_train = X[:num_train]
X_test = X[num_train:]

# For Y
Y_train = Y[:num_train]
Y_test = Y[num_train:]

# Shuffle the training data
idx = np.random.permutation(len(X_train))
X_train = X_train[idx]
Y_train = Y_train[idx]

n_classes = len(np.unique(Y_train))

# %%
Y
# Out:
# array([[0, 6, 8, 4, 4],
#        [6, 6, 3, 8, 9],
#        [6, 6, 5, 1, 7],
#        ...,
#        [9, 9, 3, 8, 5],
#        [1, 5, 7, 9, 2],
#        [9, 5, 6, 6, 0]])

# %%
from sklearn.manifold import TSNE
import plotly.graph_objects as go

# Flatten your data and apply t-SNE
X_flat = X.reshape(X.shape[0], -1)
X_tsne = TSNE(n_components=3).fit_transform(X_flat)

# Create a DataFrame with the t-SNE components and the labels
df_tsne = pd.DataFrame({
    'Component 1': X_tsne[:, 0],
    'Component 2': X_tsne[:, 1],
    'Component 3': X_tsne[:, 2],
    'Digit': Y.flatten()  # Assuming Y is a 1D array with the same length as X
})

# Create a 3D scatter plot of the t-SNE components
fig = go.Figure(data=[go.Scatter3d(
    x=df_tsne['Component 1'],
    y=df_tsne['Component 2'],
    z=df_tsne['Component 3'],
    mode='markers',
    marker=dict(
        size=2,
        color=df_tsne['Digit'],  # set color to an array/list of desired values
        colorscale='Viridis',    # choose a colorscale
        opacity=0.8
    )
)])

# Set the layout
fig.update_layout(
    title = "3D t-SNE plot of EEG data",
    scene = dict(
        xaxis_title='Component 1',
        yaxis_title='Component 2',
        zaxis_title='Component 3'
    )
)

# Show the figure
fig.show()

# %%
X_train.shape, Y_train.shape
# Out:
# ((2088, 1400, 5), (2088, 5))

# %% [markdown]
# ## Build the model
#
# Our model processes a tensor of shape `(batch size, sequence length, features)`,
# where `sequence length` is the number of time steps and `features` is each input
# timeseries.
#
# You can replace your classification RNN layers with this one: the
# inputs are fully compatible!

# %% [markdown]
# We include residual connections, layer normalization, and dropout.
# The resulting layer can be stacked multiple times.
#
# The projection layers are implemented through `keras.layers.Conv1D`.

# %% [markdown]
# The main part of our model is now complete. We can stack multiple of those
# `transformer_encoder` blocks and we can also proceed to add the final
# Multi-Layer Perceptron classification head. Apart from a stack of `Dense`
# layers, we need to reduce the output tensor of the `TransformerEncoder` part of
# our model down to a vector of features for each data point in the current
# batch. A common way to achieve this is to use a pooling layer. For
# this example, a `GlobalAveragePooling1D` layer is sufficient.

# %%
from tensorflow import keras
from tensorflow.keras import layers
import wandb
from wandb.keras import WandbCallback

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    x = layers.Dense(n_classes, activation="linear")(x) # set units to n_classes and use linear
    outputs = [layers.Dense(n_classes, activation="softmax")(x) for _ in range(5)] # 5 outputs each with 10 probabilities
    return keras.Model(inputs, outputs)

input_shape = X_train.shape[1:]

wandb.init(project="mindbigdata")

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()

class CustomWandbCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        # compute total accuracy
        total_accuracy = np.mean([log for log in logs if log.startswith('dense_') and log.endswith('sparse_categorical_accuracy')])

        # log total accuracy to wandb
        wandb.log({'total_accuracy': total_accuracy})

callbacks = [CustomWandbCallback(), keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True), WandbCallback()]

model.fit(
    X_train,
    [Y_train[:, i] for i in range(5)], # split Y_train into 5 outputs
    validation_split=0.2,
    epochs=200,
    batch_size=4,
    callbacks=callbacks,
)

#model.evaluate(X_test, Y_test, verbose=1)
# Out:
# Finishing last run (ID:c94zfkfp) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">volcanic-snowflake-10</strong> at: <a href='https://wandb.ai/louis030195/mindbigdata/runs/c94zfkfp' target="_blank">https://wandb.ai/louis030195/mindbigdata/runs/c94zfkfp</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230716_103457-c94zfkfp/logs</code>
# Successfully finished last run (ID:c94zfkfp). Initializing new run:<br/>
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/Users/louisbeaumont/Documents/mne-hack/wandb/run-20230716_105213-j6xw2xkx</code>
# Syncing run <strong><a href='https://wandb.ai/louis030195/mindbigdata/runs/j6xw2xkx' target="_blank">wandering-brook-11</a></strong> to <a href='https://wandb.ai/louis030195/mindbigdata' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/louis030195/mindbigdata' target="_blank">https://wandb.ai/louis030195/mindbigdata</a>
#  View run at <a href='https://wandb.ai/louis030195/mindbigdata/runs/j6xw2xkx' target="_blank">https://wandb.ai/louis030195/mindbigdata/runs/j6xw2xkx</a>
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 1400, 5)]            0         []
#
#  layer_normalization_24 (La  (None, 1400, 5)              10        ['input_4[0][0]']
#  yerNormalization)
#
#  multi_head_attention_12 (M  (None, 1400, 5)              23557     ['layer_normalization_24[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_24[0][0]
#                                                                     ']
#
#  dropout_27 (Dropout)        (None, 1400, 5)              0         ['multi_head_attention_12[0][0
#                                                                     ]']
#
#  tf.__operators__.add_24 (T  (None, 1400, 5)              0         ['dropout_27[0][0]',
#  FOpLambda)                                                          'input_4[0][0]']
#
#  layer_normalization_25 (La  (None, 1400, 5)              10        ['tf.__operators__.add_24[0][0
#  yerNormalization)                                                  ]']
#
#  conv1d_24 (Conv1D)          (None, 1400, 4)              24        ['layer_normalization_25[0][0]
#                                                                     ']
#
#  dropout_28 (Dropout)        (None, 1400, 4)              0         ['conv1d_24[0][0]']
#
#  conv1d_25 (Conv1D)          (None, 1400, 5)              25        ['dropout_28[0][0]']
#
#  tf.__operators__.add_25 (T  (None, 1400, 5)              0         ['conv1d_25[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_24[0][0
#                                                                     ]']
#
#  layer_normalization_26 (La  (None, 1400, 5)              10        ['tf.__operators__.add_25[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_13 (M  (None, 1400, 5)              23557     ['layer_normalization_26[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_26[0][0]
#                                                                     ']
#
#  dropout_29 (Dropout)        (None, 1400, 5)              0         ['multi_head_attention_13[0][0
#                                                                     ]']
#
#  tf.__operators__.add_26 (T  (None, 1400, 5)              0         ['dropout_29[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_25[0][0
#                                                                     ]']
#
#  layer_normalization_27 (La  (None, 1400, 5)              10        ['tf.__operators__.add_26[0][0
#  yerNormalization)                                                  ]']
#
#  conv1d_26 (Conv1D)          (None, 1400, 4)              24        ['layer_normalization_27[0][0]
#                                                                     ']
#
#  dropout_30 (Dropout)        (None, 1400, 4)              0         ['conv1d_26[0][0]']
#
#  conv1d_27 (Conv1D)          (None, 1400, 5)              25        ['dropout_30[0][0]']
#
#  tf.__operators__.add_27 (T  (None, 1400, 5)              0         ['conv1d_27[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_26[0][0
#                                                                     ]']
#
#  layer_normalization_28 (La  (None, 1400, 5)              10        ['tf.__operators__.add_27[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_14 (M  (None, 1400, 5)              23557     ['layer_normalization_28[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_28[0][0]
#                                                                     ']
#
#  dropout_31 (Dropout)        (None, 1400, 5)              0         ['multi_head_attention_14[0][0
#                                                                     ]']
#
#  tf.__operators__.add_28 (T  (None, 1400, 5)              0         ['dropout_31[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_27[0][0
#                                                                     ]']
#
#  layer_normalization_29 (La  (None, 1400, 5)              10        ['tf.__operators__.add_28[0][0
#  yerNormalization)                                                  ]']
#
#  conv1d_28 (Conv1D)          (None, 1400, 4)              24        ['layer_normalization_29[0][0]
#                                                                     ']
#
#  dropout_32 (Dropout)        (None, 1400, 4)              0         ['conv1d_28[0][0]']
#
#  conv1d_29 (Conv1D)          (None, 1400, 5)              25        ['dropout_32[0][0]']
#
#  tf.__operators__.add_29 (T  (None, 1400, 5)              0         ['conv1d_29[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_28[0][0
#                                                                     ]']
#
#  layer_normalization_30 (La  (None, 1400, 5)              10        ['tf.__operators__.add_29[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_15 (M  (None, 1400, 5)              23557     ['layer_normalization_30[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_30[0][0]
#                                                                     ']
#
#  dropout_33 (Dropout)        (None, 1400, 5)              0         ['multi_head_attention_15[0][0
#                                                                     ]']
#
#  tf.__operators__.add_30 (T  (None, 1400, 5)              0         ['dropout_33[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_29[0][0
#                                                                     ]']
#
#  layer_normalization_31 (La  (None, 1400, 5)              10        ['tf.__operators__.add_30[0][0
#  yerNormalization)                                                  ]']
#
#  conv1d_30 (Conv1D)          (None, 1400, 4)              24        ['layer_normalization_31[0][0]
#                                                                     ']
#
#  dropout_34 (Dropout)        (None, 1400, 4)              0         ['conv1d_30[0][0]']
#
#  conv1d_31 (Conv1D)          (None, 1400, 5)              25        ['dropout_34[0][0]']
#
#  tf.__operators__.add_31 (T  (None, 1400, 5)              0         ['conv1d_31[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_30[0][0
#                                                                     ]']
#
#  global_average_pooling1d_3  (None, 1400)                 0         ['tf.__operators__.add_31[0][0
#   (GlobalAveragePooling1D)                                          ]']
#
#  dense_21 (Dense)            (None, 128)                  179328    ['global_average_pooling1d_3[0
#                                                                     ][0]']
#
#  dropout_35 (Dropout)        (None, 128)                  0         ['dense_21[0][0]']
#
#  dense_22 (Dense)            (None, 10)                   1290      ['dropout_35[0][0]']
#
#  dense_23 (Dense)            (None, 10)                   110       ['dense_22[0][0]']
#
#  dense_24 (Dense)            (None, 10)                   110       ['dense_22[0][0]']
#
#  dense_25 (Dense)            (None, 10)                   110       ['dense_22[0][0]']
#
#  dense_26 (Dense)            (None, 10)                   110       ['dense_22[0][0]']
#
#  dense_27 (Dense)            (None, 10)                   110       ['dense_22[0][0]']
#
# ==================================================================================================
# Total params: 275672 (1.05 MB)
# Trainable params: 275672 (1.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/200
# 418/418 [==============================] - ETA: 0s - loss: 11.7037 - dense_23_loss: 2.3462 - dense_24_loss: 2.3423 - dense_25_loss: 2.3439 - dense_26_loss: 2.3431 - dense_27_loss: 2.3283 - dense_23_sparse_categorical_accuracy: 0.0976 - dense_24_sparse_categorical_accuracy: 0.0946 - dense_25_sparse_categorical_accuracy: 0.0868 - dense_26_sparse_categorical_accuracy: 0.0958 - dense_27_sparse_categorical_accuracy: 0.1036
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[7], line 77
#      73         wandb.log({'total_accuracy': total_accuracy})
#      75 callbacks = [CustomWandbCallback(), keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True), WandbCallback()]
# ---> 77 model.fit(
#      78     X_train,
#      79     [Y_train[:, i] for i in range(5)], # split Y_train into 5 outputs
#      80     validation_split=0.2,
#      81     epochs=200,
#      82     batch_size=4,
#      83     callbacks=callbacks,
#      84 )
#      86 #model.evaluate(X_test, Y_test, verbose=1)
#
# File ~/Documents/mne-hack/env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# Cell In[7], line 70, in CustomWandbCallback.on_epoch_end(self, epoch, logs)
#      68 def on_epoch_end(self, epoch, logs=None):
#      69     # compute total accuracy
# ---> 70     total_accuracy = np.mean([log for log in logs if log.startswith('dense_') and log.endswith('sparse_categorical_accuracy')])
#      72     # log total accuracy to wandb
#      73     wandb.log({'total_accuracy': total_accuracy})
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File ~/Documents/mne-hack/env/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3464, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
#    3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File ~/Documents/mne-hack/env/lib/python3.10/site-packages/numpy/core/_methods.py:181, in _mean(a, axis, dtype, out, keepdims, where)
#     178         dtype = mu.dtype('f4')
#     179         is_float16_result = True
# --> 181 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     182 if isinstance(ret, mu.ndarray):
#     183     with _no_nep50_warning():
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U36'), dtype('<U36')) -> None

# %%
X_train.shape
# display all length on dim 1
for i in range(len(X_train)):
    print(len(X_train[i]))
# Out:
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088
# 1088

# %%
[Y_train[:, i] for i in range(5)]
# Out:
# [array([1, 9, 9, ..., 4, 8, 7]),
#  array([0, 8, 1, ..., 7, 6, 4]),
#  array([2, 9, 2, ..., 2, 0, 4]),
#  array([9, 2, 3, ..., 7, 5, 2]),
#  array([2, 1, 9, ..., 0, 9, 1])]

# %% [markdown]
# ## Conclusions
#
# In about 110-120 epochs (25s each on Colab), the model reaches a training
# accuracy of ~0.95, validation accuracy of ~84 and a testing
# accuracy of ~85, without hyperparameter tuning. And that is for a model
# with less than 100k parameters. Of course, parameter count and accuracy could be
# improved by a hyperparameter search and a more sophisticated learning rate
# schedule, or a different optimizer.
#
# You can use the trained model hosted on [Hugging Face Hub](https://huggingface.co/keras-io/timeseries_transformer_classification) and try the demo on [Hugging Face Spaces](https://huggingface.co/spaces/keras-io/timeseries_transformer_classification).
